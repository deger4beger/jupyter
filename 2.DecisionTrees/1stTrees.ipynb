# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.DataFrame({'X_1': [1, 1, 1, 0, 0, 0, 0, 1], 'X_2': [0, 0, 0, 1, 0, 0, 0, 1], 'Y': [1, 1, 1, 1, 0, 0, 0, 0]})
# sns.set_style("whitegrid")
# sns.set(rc={'figure.figsize': (12, 6)})

# %%
data
# Out:
#    X_1  X_2  Y
# 0    1    0  1
# 1    1    0  1
# 2    1    0  1
# 3    0    1  1
# 4    0    0  0
# 5    0    0  0
# 6    0    0  0
# 7    1    1  0

# %%
clf = tree.DecisionTreeClassifier(criterion="entropy")

# %%
X = data[["X_1", "X_2"]]
y = data.Y

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf, feature_names=list(X),
               class_names=['Negative', 'Positive'],
               filled=True, max_depth=4,fontsize=5)
# Out:
# [Text(465.0, 755.0, 'X_1 <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Negative'),
#  Text(232.5, 453.0, 'X_2 <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Negative'),
#  Text(116.25, 151.0, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Negative'),
#  Text(348.75, 151.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Positive'),
#  Text(697.5, 453.0, 'X_2 <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Positive'),
#  Text(581.25, 151.0, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Positive'),
#  Text(813.75, 151.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Negative')]

# %%
data = pd.read_csv("D:\\python\\jupyter\\files\\dogs.csv", index_col=0)

# %%
data = data.rename(columns={"Лазает по деревьям": "Лазает_по_деревьям"})

# %%
X = data[["Шерстист", "Гавкает", "Лазает_по_деревьям"]]
y = data.Вид

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf, feature_names=list(X),
               class_names=['Negative', 'Positive'],
               filled=True, max_depth=4,fontsize=5)
# Out:
# [Text(465.0, 679.5, 'Гавкает <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Negative'),
#  Text(232.5, 226.5, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = Negative'),
#  Text(697.5, 226.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Positive')]

# %%
data = pd.read_csv("https://stepik.org/media/attachments/course/4852/cats.csv", index_col=0)

# %%
data
# Out:
#    Шерстист  Гавкает  Лазает по деревьям      Вид
# 0         1        1                   0  собачка
# 1         1        1                   0  собачка
# 2         1        1                   0  собачка
# 3         1        1                   0  собачка
# 4         1        0                   1    котик
# 5         1        0                   1    котик
# 6         1        0                   1    котик
# 7         1        0                   1    котик
# 8         1        1                   1    котик
# 9         0        0                   1    котик

# %%
data = data.rename(columns={"Лазает по деревьям": "Лазает_по_деревьям"})

# %%
X = data[["Шерстист", "Гавкает", "Лазает_по_деревьям"]]
y = data.Вид

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf, feature_names=list(X),
               class_names=['Negative', 'Positive'],
               filled=True, max_depth=4,fontsize=5)
# Out:
# [Text(465.0, 679.5, 'Лазает_по_деревьям <= 0.5\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]\nclass = Negative'),
#  Text(232.5, 226.5, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = Positive'),
#  Text(697.5, 226.5, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = Negative')]

# %%
np.log2(1/5)
# Out:
# -2.321928094887362
