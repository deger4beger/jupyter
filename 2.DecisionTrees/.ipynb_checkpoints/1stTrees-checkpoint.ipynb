# %%
from sklearn import tree
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.DataFrame({'X_1': [1, 1, 1, 0, 0, 0, 0, 1], 'X_2': [0, 0, 0, 1, 0, 0, 0, 1], 'Y': [1, 1, 1, 1, 0, 0, 0, 0]})
# sns.set_style("whitegrid")
# sns.set(rc={'figure.figsize': (12, 6)})

# %%
data
# Out:
#    X_1  X_2  Y
# 0    1    0  1
# 1    1    0  1
# 2    1    0  1
# 3    0    1  1
# 4    0    0  0
# 5    0    0  0
# 6    0    0  0
# 7    1    1  0

# %%
clf = tree.DecisionTreeClassifier(criterion="entropy")

# %%
X = data[["X_1", "X_2"]]
y = data.Y

# %%
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
fig, ax = plt.subplots(figsize=(12, 8))
tree.plot_tree(clf, feature_names=list(X),
               class_names=['Negative', 'Positive'],
               filled=True, max_depth=4,fontsize=16)
# Out:
# [Text(334.8, 362.4, 'X_1 <= 0.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]\nclass = Negative'),
#  Text(167.4, 217.44, 'X_2 <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]\nclass = Negative'),
#  Text(83.7, 72.47999999999996, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = Negative'),
#  Text(251.10000000000002, 72.47999999999996, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = Positive'),
#  Text(502.20000000000005, 217.44, 'X_2 <= 0.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]\nclass = Positive'),
#  Text(418.5, 72.47999999999996, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]\nclass = Positive'),
#  Text(585.9, 72.47999999999996, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = Negative')]
