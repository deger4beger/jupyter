# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv("D:\\python\\jupyter\\files\\StudentsPerformance.csv")

# %%
students_performance.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
type_lunch_reduced = students_performance[students_performance.lunch == "free/reduced"]

# %%
type_lunch_reduced.describe()
# Out:
#        math score  reading score  writing score
# count  355.000000     355.000000     355.000000
# mean    58.921127      64.653521      63.022535
# std     15.159956      14.895339      15.433823
# min      0.000000      17.000000      10.000000
# 25%     49.000000      56.000000      53.000000
# 50%     60.000000      65.000000      64.000000
# 75%     69.000000      75.000000      74.000000
# max    100.000000     100.000000     100.000000

# %%
type_lunch_standard = students_performance[students_performance.lunch == "standard"]

# %%
type_lunch_standard.describe()
# Out:
#        math score  reading score  writing score
# count  645.000000     645.000000     645.000000
# mean    70.034109      71.654264      70.823256
# std     13.653501      13.830602      14.339487
# min     19.000000      26.000000      22.000000
# 25%     61.000000      63.000000      62.000000
# 50%     69.000000      72.000000      72.000000
# 75%     80.000000      82.000000      81.000000
# max    100.000000     100.000000     100.000000

# %%
mean_writing_score = students_performance["writing score"].mean()

# %%
query = (students_performance['writing score'] > mean_writing_score) & (students_performance.gender == 'female')

# %%
students_performance.loc[query]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.loc[students_performance["writing score"] > mean_writing_score]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_performance.loc[students_performance.gender == "female", ["gender", "writing score"]]
# Out:
#      gender  writing score
# 0    female             74
# 1    female             88
# 2    female             93
# 5    female             78
# 6    female             92
# ..      ...            ...
# 993  female             74
# 995  female             95
# 997  female             65
# 998  female             77
# 999  female             86
#
# [518 rows x 2 columns]

# %%
students_performance.columns = [x.replace(" ", "_") for x in students_performance.columns]

# %%
students_performance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
writing_score_query = 80

# %%
students_performance.query("writing_score > @writing_score_query & gender == 'female'")
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 36   female        group D          associate's degree      standard
# 38   female        group D          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance[students_performance['parental_level_of_education'].isin(["some college", "some high school"])]
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 4      male        group C                some college      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 13     male        group A                some college      standard
# ..      ...            ...                         ...           ...
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 991  female        group B            some high school      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
variants = ['72', '90']

# %%
students_performance[["race_ethnicity"]] = "wtf is this"

# %%
students_performance = students_performance.rename(columns = {"race/ethnicity": "race_ethnicity"})

# %%
students_performance
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female    wtf is this           bachelor's degree      standard
# 1    female    wtf is this                some college      standard
# 2    female    wtf is this             master's degree      standard
# 3      male    wtf is this          associate's degree  free/reduced
# 4      male    wtf is this                some college      standard
# ..      ...            ...                         ...           ...
# 995  female    wtf is this             master's degree      standard
# 996    male    wtf is this                 high school  free/reduced
# 997  female    wtf is this                 high school  free/reduced
# 998  female    wtf is this                some college      standard
# 999  female    wtf is this                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
students_performance.query("math_score == @variants")
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female    wtf is this           bachelor's degree      standard
# 2    female    wtf is this             master's degree      standard
# 83     male    wtf is this          associate's degree      standard
# 126    male    wtf is this            some high school      standard
# 170    male    wtf is this                 high school      standard
# 226  female    wtf is this                some college      standard
# 299    male    wtf is this          associate's degree  free/reduced
# 333    male    wtf is this          associate's degree      standard
# 345  female    wtf is this                 high school      standard
# 459    male    wtf is this                 high school      standard
# 467    male    wtf is this                 high school  free/reduced
# 474  female    wtf is this          associate's degree      standard
# 547    male    wtf is this                 high school      standard
# ...

# %%
score_columns = [i for i in list(students_performance) if "score" in i]

# %%
students_performance[score_columns].head()
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
students_performance.filter(like="score", axis=1).head() # axis - колонки, 0 - строчки
# Out:
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
students_performance_with_names = students_performance.iloc[:5]

# %%
students_performance_with_names.index = ["Sersei", "Vlad", "Danil", "Masha", "Kasha"]

# %%
students_performance_with_names
# Out:
#         gender race_ethnicity parental_level_of_education         lunch  \
# Sersei  female    wtf is this           bachelor's degree      standard
# Vlad    female    wtf is this                some college      standard
# Danil   female    wtf is this             master's degree      standard
# Masha     male    wtf is this          associate's degree  free/reduced
# Kasha     male    wtf is this                some college      standard
#
#        test_preparation_course  math_score  reading_score  writing_score
# Sersei                    none          72             72             74
# Vlad                 completed          69             90             88
# Danil                     none          90             95             93
# Masha                     none          47             57             44
# Kasha                     none          76             78             75

# %%
students_performance_with_names.filter(like="a", axis=0)
# Out:
#        gender race_ethnicity parental_level_of_education         lunch  \
# Vlad   female    wtf is this                some college      standard
# Danil  female    wtf is this             master's degree      standard
# Masha    male    wtf is this          associate's degree  free/reduced
# Kasha    male    wtf is this                some college      standard
#
#       test_preparation_course  math_score  reading_score  writing_score
# Vlad                completed          69             90             88
# Danil                    none          90             95             93
# Masha                    none          47             57             44
# Kasha                    none          76             78             75

# %%
students_performance_with_names.select_dtypes(include="int64")
# Out:
#         math_score  reading_score  writing_score
# Sersei          72             72             74
# Vlad            69             90             88
# Danil           90             95             93
# Masha           47             57             44
# Kasha           76             78             75

# %%
students_performance_with_names.select_dtypes(exclude="int64")
# Out:
#         gender race_ethnicity parental_level_of_education         lunch  \
# Sersei  female    wtf is this           bachelor's degree      standard
# Vlad    female    wtf is this                some college      standard
# Danil   female    wtf is this             master's degree      standard
# Masha     male    wtf is this          associate's degree  free/reduced
# Kasha     male    wtf is this                some college      standard
#
#        test_preparation_course
# Sersei                    none
# Vlad                 completed
# Danil                     none
# Masha                     none
# Kasha                     none

# %%
students_performance_with_names.filter(items=["gender","lunch"])
# Out:
#         gender         lunch
# Sersei  female      standard
# Vlad    female      standard
# Danil   female      standard
# Masha     male  free/reduced
# Kasha     male      standard
