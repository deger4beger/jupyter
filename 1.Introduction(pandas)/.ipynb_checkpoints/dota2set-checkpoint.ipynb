# %%
import pandas as pd
import numpy as np

# %%
students_performance = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")

# %%
students_performance.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
students_performance.groupby("legs").describe()
# Out:
#      Unnamed: 0                                                         id  \
#           count       mean        std   min   25%   50%   75%    max count
# legs
# 0          11.0  46.000000  32.227318   9.0  20.0  38.0  76.0   92.0  11.0
# 2          95.0  58.789474  34.307091   0.0  29.5  58.0  86.5  116.0  95.0
# 4           7.0  61.714286  31.721256   2.0  53.0  61.0  84.0   95.0   7.0
# 6           3.0  68.000000  46.679760  15.0  50.5  86.0  94.5  103.0   3.0
# 8           1.0  59.000000        NaN  59.0  59.0  59.0  59.0   59.0   1.0
#
#
#            mean        std   min   25%   50%   75%    max
# legs
# 0     47.727273  32.554849  10.0  21.5  40.0  78.0   94.0
# 2     60.842105  34.994928   1.0  31.5  60.0  88.5  129.0
# 4     63.571429  32.035694   3.0  55.0  63.0  86.0   97.0
# 6     69.666667  47.247575  16.0  52.0  88.0  96.5  105.0
# 8     61.000000        NaN  61.0  61.0  61.0  61.0   61.0

# %%
students_performance.groupby(["attack_type", "primary_attr"]).count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
students_performance.groupby(["attack_type", "primary_attr"]).apply(lambda x: x.mode().loc[:, "roles"])
# Out:
# attack_type  primary_attr
# Melee        agi           0     ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
#                            1                        ['Carry', 'Durable', 'Escape']
#                            2          ['Carry', 'Escape', 'Disabler', 'Initiator']
#                            3              ['Carry', 'Escape', 'Disabler', 'Nuker']
#                            4                       ['Carry', 'Escape', 'Disabler']
#                                                        ...
# Ranged       int           38                                                  NaN
#                            39                                                  NaN
#              str           0                     ['Carry', 'Durable', 'Initiator']
#                            1                        ['Support', 'Escape', 'Nuker']
#                            2     ['Support', 'Nuker', 'Initiator', 'Escape', 'D...
# Name: roles, Length: 117, dtype: object

# %%
students_performance.groupby(["attack_type", "primary_attr"]).aggregate({"roles": "count"})
# Out:
#                           roles
# attack_type primary_attr
# Melee       agi              19
#             int               2
#             str              35
# Ranged      agi              18
#             int              40
#             str               3
